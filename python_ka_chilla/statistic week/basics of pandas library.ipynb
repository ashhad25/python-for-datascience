# %% [markdown]
# ## This notebook is all about pandas library

# %%
# importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# - we can create object series

# %%
s = pd.Series([1, 3, np.nan, 5, 6, 7, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3    5.0
# 4    6.0
# 5    7.0
# 6    8.0
# dtype: float64

# %% [markdown]
# - we can also create date series

# %%
dates = pd.date_range("20230101", periods=17)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
#  - we can create dataframe from the dates series provided above

# %%
df = pd.DataFrame(np.random.randn(17, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399
# 2023-01-02  0.017700  0.983685  0.989183  0.369986
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623
# 2023-01-06 -2.373313 -0.442792 -0.730618 -0.323181
# 2023-01-07 -1.265459  0.228850 -0.250315 -0.263162
# 2023-01-08 -0.695152  1.463510 -0.838501  0.132633
# 2023-01-09  0.877663 -0.089026  0.478956  0.121681
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060
# 2023-01-11 -0.406034 -2.795437 -1.401540 -0.089764
# 2023-01-12 -0.285114 -0.518139 -0.120991  1.085250
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868

# %% [markdown]
#  - we have created a dataframe using dictionary data structure

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20230101"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-01-01  1.0  3   test  foo
# 1  1.0 2023-01-01  1.0  3  train  foo
# 2  1.0 2023-01-01  1.0  3   test  foo
# 3  1.0 2023-01-01  1.0  3  train  foo

# %% [markdown]
# - this is how we can check datatypes of a dataframe

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# - head() method will show starting 5 rows

# %%
df.head()
# Out:
#                    A         B         C         D
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399
# 2023-01-02  0.017700  0.983685  0.989183  0.369986
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623

# %% [markdown]
# - we can also specify ammount of rows we want to see

# %%
df.head(3)
# Out:
#                    A         B         C         D
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399
# 2023-01-02  0.017700  0.983685  0.989183  0.369986
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522

# %% [markdown]
# - tail() method will show us the bottom 5 rows and to see specific rows we can pass the ammount as argument

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868

# %% [markdown]
# - we can also check for index using index variable

# %%
print(df.index)
print(df2.index)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17'],
#               dtype='datetime64[ns]', freq='D')
# Int64Index([0, 1, 2, 3], dtype='int64')

# %% [markdown]
# - to convert our dataframe to array we can use to_numpy() method

# %%
array = df2.to_numpy()
array
# Out:
# array([[1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-01-01 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %% [markdown]
# - we can check type using type() method

# %%
type(array)
# Out:
# numpy.ndarray

# %% [markdown]
# - we can check summary of or dataframe
#   - using describe() method

# %%
df.describe()
# Out:
#                A          B          C          D
# count  17.000000  17.000000  17.000000  17.000000
# mean   -0.270974   0.038749   0.204972   0.201939
# std     1.127029   1.036421   0.825470   0.925481
# min    -2.373313  -2.795437  -1.401540  -1.522060
# 25%    -0.865017  -0.348066  -0.250315  -0.323181
# 50%    -0.285114  -0.086345   0.227353   0.115649
# 75%     0.260325   0.228850   0.989183   1.007868
# max     2.011899   1.599879   1.488175   1.914399

# %% [markdown]
# - to transpose data
#   - use T variable to transpose it

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2023-01-01 00:00:00  2023-01-01 00:00:00  2023-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2023-01-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %% [markdown]
# - we can sort on the basis of index
#   - using sort_index() method

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649
# 2023-01-12 -0.285114 -0.518139 -0.120991  1.085250
# 2023-01-11 -0.406034 -2.795437 -1.401540 -0.089764
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060
# 2023-01-09  0.877663 -0.089026  0.478956  0.121681
# 2023-01-08 -0.695152  1.463510 -0.838501  0.132633
# 2023-01-07 -1.265459  0.228850 -0.250315 -0.263162
# 2023-01-06 -2.373313 -0.442792 -0.730618 -0.323181
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522
# 2023-01-02  0.017700  0.983685  0.989183  0.369986
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399

# %% [markdown]
# - we can also use sort_values() method to sort on basis of particular row

# %%
df.sort_values(by="B", ascending=False)
# Out:
#                    A         B         C         D
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920
# 2023-01-08 -0.695152  1.463510 -0.838501  0.132633
# 2023-01-02  0.017700  0.983685  0.989183  0.369986
# 2023-01-07 -1.265459  0.228850 -0.250315 -0.263162
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564
# 2023-01-09  0.877663 -0.089026  0.478956  0.121681
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587
# 2023-01-06 -2.373313 -0.442792 -0.730618 -0.323181
# 2023-01-12 -0.285114 -0.518139 -0.120991  1.085250
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060
# 2023-01-11 -0.406034 -2.795437 -1.401540 -0.089764

# %%
df["B"]
# Out:
# 2023-01-01   -0.245075
# 2023-01-02    0.983685
# 2023-01-03   -0.253261
# 2023-01-04   -0.348066
# 2023-01-05    0.022962
# 2023-01-06   -0.442792
# 2023-01-07    0.228850
# 2023-01-08    1.463510
# 2023-01-09   -0.089026
# 2023-01-10   -0.671494
# 2023-01-11   -2.795437
# 2023-01-12   -0.518139
# 2023-01-13    0.142533
# 2023-01-14    0.095269
# 2023-01-15    1.571684
# 2023-01-16   -0.086345
# 2023-01-17    1.599879
# Freq: D, Name: B, dtype: float64

# %%
# row wise selection
df[0:3]
# Out:
#                    A         B         C         D
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399
# 2023-01-02  0.017700  0.983685  0.989183  0.369986
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522

# %%
df.loc[dates[2]]
# Out:
# A    0.285547
# B   -0.253261
# C    1.067338
# D    1.597522
# Name: 2023-01-03 00:00:00, dtype: float64

# %%
df.loc[:, ["C", "A"]]
# Out:
#                    C         A
# 2023-01-01  0.268088  0.135794
# 2023-01-02  0.989183  0.017700
# 2023-01-03  1.067338  0.285547
# 2023-01-04 -0.710089  0.138256
# 2023-01-05  0.135902 -0.427182
# 2023-01-06 -0.730618 -2.373313
# 2023-01-07 -0.250315 -1.265459
# 2023-01-08 -0.838501 -0.695152
# 2023-01-09  0.478956  0.877663
# 2023-01-10  1.488175 -0.865017
# 2023-01-11 -1.401540 -0.406034
# 2023-01-12 -0.120991 -0.285114
# 2023-01-13 -0.012777  1.324070
# 2023-01-14  0.227353 -1.258389
# 2023-01-15  0.491421  2.011899
# 2023-01-16  1.228034  0.260325
# 2023-01-17  1.174911 -2.082148

# %% [markdown]
# - the below code will display us 2023-01-04 to 2023-01-08 data with column A and B values

# %%
df.loc["20230104":"20230108", ["A","B"]]
# Out:
#                    A         B
# 2023-01-04  0.138256 -0.348066
# 2023-01-05 -0.427182  0.022962
# 2023-01-06 -2.373313 -0.442792
# 2023-01-07 -1.265459  0.228850
# 2023-01-08 -0.695152  1.463510

# %% [markdown]
# - the below code will display us 2023-01-04 and 2023-01-08 data with column A and B values

# %%
df.loc[["20230104","20230108"], ["A","B"]]
# Out:
#                    A         B
# 2023-01-04  0.138256 -0.348066
# 2023-01-08 -0.695152  1.463510

# %%
df.at[dates[0], "A"]
# Out:
# 0.13579385570793656

# %%
df[df["C"] > 1.2]
# Out:
#                    A         B         C         D
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564

# %%
[df[["A", "C"]] > 1.2]
# Out:
# [                A      C
#  2023-01-01  False  False
#  2023-01-02  False  False
#  2023-01-03  False  False
#  2023-01-04  False  False
#  2023-01-05  False  False
#  2023-01-06  False  False
#  2023-01-07  False  False
#  2023-01-08  False  False
#  2023-01-09  False  False
#  2023-01-10  False   True
#  2023-01-11  False  False
#  2023-01-12  False  False
#  2023-01-13   True  False
#  2023-01-14  False  False
#  2023-01-15   True  False
#  2023-01-16  False   True
#  2023-01-17  False  False]

# %% [markdown]
# - to copy a dataframe
#   - use copy() method

# %%
copy_df = df.copy()

# %% [markdown]
# - we can add an aditional column by the way down below

# %%
copy_df["E"] = ["one", "one", "two", "three", "four", "three","one", "one", "two", "three", "four", "three","one", "one", "two", "three", "four"]
copy_df
# Out:
#                    A         B         C         D      E
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399    one
# 2023-01-02  0.017700  0.983685  0.989183  0.369986    one
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522    two
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587  three
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623   four
# 2023-01-06 -2.373313 -0.442792 -0.730618 -0.323181  three
# 2023-01-07 -1.265459  0.228850 -0.250315 -0.263162    one
# 2023-01-08 -0.695152  1.463510 -0.838501  0.132633    one
# 2023-01-09  0.877663 -0.089026  0.478956  0.121681    two
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060  three
# 2023-01-11 -0.406034 -2.795437 -1.401540 -0.089764   four
# 2023-01-12 -0.285114 -0.518139 -0.120991  1.085250  three
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649    one
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294    one
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920    two
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564  three
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868   four

# %%
df4 = df[["A", "B", "C", "D"]].mean()
df4
# Out:
# A   -0.270974
# B    0.038749
# C    0.204972
# D    0.201939
# dtype: float64

# %% [markdown]
# - below is the way you can actually find the mean and add that to column

# %%
me =[]
for a in range(0, 17):
    new  = df.loc[dates[a]].mean()
    me.append(new)

copy_df["mean"] = me
copy_df
# Out:
#                    A         B         C         D      E      mean
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399    one  0.518302
# 2023-01-02  0.017700  0.983685  0.989183  0.369986    one  0.590139
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522    two  0.674287
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587  three -0.391871
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623   four -0.081485
# 2023-01-06 -2.373313 -0.442792 -0.730618 -0.323181  three -0.967476
# 2023-01-07 -1.265459  0.228850 -0.250315 -0.263162    one -0.387521
# 2023-01-08 -0.695152  1.463510 -0.838501  0.132633    one  0.015622
# 2023-01-09  0.877663 -0.089026  0.478956  0.121681    two  0.347318
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060  three -0.392599
# 2023-01-11 -0.406034 -2.795437 -1.401540 -0.089764   four -1.173194
# 2023-01-12 -0.285114 -0.518139 -0.120991  1.085250  three  0.040252
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649    one  0.392369
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294    one -0.396765
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920    two  0.833771
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564  three  0.696144
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868   four  0.425127

# %%
del copy_df["E"]

# %%
copy_df
# Out:
#                    A         B         C         D      mean
# 2023-01-01  0.135794 -0.245075  0.268088  1.914399  0.518302
# 2023-01-02  0.017700  0.983685  0.989183  0.369986  0.590139
# 2023-01-03  0.285547 -0.253261  1.067338  1.597522  0.674287
# 2023-01-04  0.138256 -0.348066 -0.710089 -0.647587 -0.391871
# 2023-01-05 -0.427182  0.022962  0.135902 -0.057623 -0.081485
# 2023-01-06 -2.373313 -0.442792 -0.730618 -0.323181 -0.967476
# 2023-01-07 -1.265459  0.228850 -0.250315 -0.263162 -0.387521
# 2023-01-08 -0.695152  1.463510 -0.838501  0.132633  0.015622
# 2023-01-09  0.877663 -0.089026  0.478956  0.121681  0.347318
# 2023-01-10 -0.865017 -0.671494  1.488175 -1.522060 -0.392599
# 2023-01-11 -0.406034 -2.795437 -1.401540 -0.089764 -1.173194
# 2023-01-12 -0.285114 -0.518139 -0.120991  1.085250  0.040252
# 2023-01-13  1.324070  0.142533 -0.012777  0.115649  0.392369
# 2023-01-14 -1.258389  0.095269  0.227353 -0.651294 -0.396765
# 2023-01-15  2.011899  1.571684  0.491421 -0.739920  0.833771
# 2023-01-16  0.260325 -0.086345  1.228034  1.382564  0.696144
# 2023-01-17 -2.082148  1.599879  1.174911  1.007868  0.425127
